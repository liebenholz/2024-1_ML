# %% [markdown]
# # Installing Libraries

# %%
# !pip install -q numpy pandas altair scikit-learn hyperopt sklearn-genetic-opt optunity optuna hpbandster
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 13.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.1/380.1 kB 15.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 kB 6.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.4/135.4 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 22.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 18.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 5.4 MB/s eta 0:00:00
#   Building wheel for optunity (setup.py) ... done
#   Building wheel for hpbandster (setup.py) ... done
#   Building wheel for netifaces (setup.py) ... done

# %% [markdown]
# 이번 실습에서는 여러 개의 라이브러리가 필요하다. 설치할 라이브러리는 다음과 같다:
# * [hyperopt](https://hyperopt.github.io/hyperopt/): Simulated Annealing을 활용한 초매개변수 최적화
# * [sklearn-genetic-opt](https://sklearn-genetic-opt.readthedocs.io/en/stable/index.html): Genetic algorithm을 활용한 초매개변수 최적화
# * [optunity](https://optunity.readthedocs.io/en/latest/index.html): Particle Swarm Optimization을 활용한 초매개변수 최적화
# * [optuna](https://optuna.readthedocs.io/en/stable/index.html): Successive Halving, Hyperband를 활용한 초매개변수 최적화
# * [HpBandSter](https://automl.github.io/HpBandSter/build/html/index.html): Bayesian Optimization and Hyperband를 활용한 초매개변수 최적화

# %% [markdown]
# # Data Preparation

# %% [markdown]
# 데이터로는 지난 시간에도 사용했던 은행의 전화 마케팅 성공 여부를 예측하는 [Banking Dataset - Marketing Targets](https://www.kaggle.com/datasets/prakharrathi25/banking-dataset-marketing-targets)을 이용한다.
#
# 지난 시간에 했던 대로 범주형 데이터는 One-hot Encoding을 통해 숫자로 바꿔주겠다.

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder


URL_DATA = 'https://drive.usercontent.google.com/download?export=download&confirm=t&id=1_XXEOnEr8hUqNhFDu8x4Z7Rvb-4ZUTcm'
DATA = pd.read_csv(URL_DATA, sep=';')
X, y = DATA.drop('y', axis=1), DATA['y']
X_NUM, X_CAT = X.select_dtypes(include='number'), X.select_dtypes(exclude='number')

encoder = OneHotEncoder(drop='if_binary', sparse_output=False)

X_CAT = pd.DataFrame(
    encoder.fit_transform(X_CAT),
    columns=encoder.get_feature_names_out()
)

X = pd.concat([X_NUM, X_CAT], axis=1)
y = y.replace({'no': 0, 'yes': 1})

# %% [markdown]
# 이제, 훈련 데이터셋과 검증 데이터셋으로 분할하자.

# %%
from sklearn.model_selection import StratifiedShuffleSplit


splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.4, random_state=42)
I_train, I_test = next(splitter.split(X, y))
X_train, y_train = X.iloc[I_train].values, y.iloc[I_train].values
X_test, y_test = X.iloc[I_test].values, y.iloc[I_test].values

# %% [markdown]
# # Default Performance

# %% [markdown]
# 먼저 기본 성능부터 다시 확인해보자.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score


model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
f1_score(y_test, y_pred, pos_label=1)
# Out:
# 0.4908759124087591

# %% [markdown]
# # Heuristic Search

# %% [markdown]
# 먼저, 이론적인 바탕보다는 시행 착오를 거쳐서 초매개변수를 탐색하는 방법인 Heuristic Search를 해보자.

# %% [markdown]
# ## Simulated Annealing

# %% [markdown]
# Simulated Annealing은 지난 시간에 사용해봤던 [hyperopt](https://github.com/hyperopt/hyperopt)에 구현되어 있다. 물론, hyperopt를 사용하는 것이니만큼, 목적 함수와 검색 공간을 정의해야 한다.

# %%
from hyperopt import hp
import numpy as np
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold


search_space = {
    'n_estimators': 5 + hp.randint('n_estimators', 195), # 5 ~ 200 사이의 정수를 균일 분포 확률Uniformly Random로 뽑는다.
    'criterion': hp.choice('criterion', ['gini', 'entropy']), # 'gini' 와 'entropy'를 중 하나를 균일 분포 확률Uniformly Random로 뽑는다.
    'max_depth': 3 + hp.randint('max_depth', 17), # 3 ~ 20 사이의 정수를 균일 분포 확률Uniformly Random로 뽑는다.
    'class_weight': hp.choice('class_weight', ['balanced', 'balanced_subsample']), # 'balanced' 와 'balanced_subsample'를 중 하나를 균일 분포 확률Uniformly Random로 뽑는다.
    'min_samples_split': hp.uniform('min_samples_split', 0.01, 0.5), # 0.01 ~ 0.5 사이의 실수를 균일 분포 확률Uniformly Random로 뽑는다.
}

def objective(hyperparams):
    splitter = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
    scores = []

    for I_train, I_test in splitter.split(X_train, y_train):
        X_inner_train, X_inner_test, y_inner_train, y_inner_test = X_train[I_train], X_train[I_test], y_train[I_train], y_train[I_test]
        model = RandomForestClassifier(random_state=42)
        model.set_params(**hyperparams)
        model.fit(X_inner_train, y_inner_train)
        y_pred = model.predict(X_inner_test)
        f1 = f1_score(y_true=y_inner_test, y_pred=y_pred, pos_label=1)
        scores.append(f1)

    return -np.mean(scores)

# %% [markdown]
# 다음은 최적화 실행이다. 아래의 코드를 확인하자.

# %%
from hyperopt import fmin, anneal


best = fmin(
    fn=objective, # 정의한 목적 함수를 입력한다.
    space=search_space, # 검색 공간을 정의한다.
    algo=anneal.suggest, # Simulated Annealing을 활용한다.
    max_evals=50 # 총 50회의 초매개변수 조합을 탐색한다.
)
# Out:
# 100%|██████████| 50/50 [03:51<00:00,  4.63s/trial, best loss: -0.5384130731151785]

# %% [markdown]
# 찾아낸 최적의 초매개변수는 다음과 같다.

# %%
best
# Out:
# {'class_weight': 0,
#  'criterion': 0,
#  'max_depth': 10,
#  'min_samples_split': 0.014733638670721999,
#  'n_estimators': 43}

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score


model = RandomForestClassifier(
    random_state=42,
    class_weight='balanced',
    criterion='gini',
    max_depth=10,
    min_samples_split=0.014733638670721999,
    n_estimators=43
).fit(X_train, y_train)

y_pred = model.predict(X_test)
f1_score(y_test, y_pred, pos_label=1)
# Out:
# 0.5285268237297758

# %% [markdown]
# ## Genetic Algorithm

# %% [markdown]
# 이번엔 여러 개체로 구성된 모집단이 서로 자연 선택, 교배, 돌연변이를 일으키면서 최적의 매개변수를 찾는 방법인 Genetic Algorithm을 실습해보자. Python 기반의 Genetic Algorithm 구현체는 [DEAP](https://deap.readthedocs.io/en/master/)가 가장 유명하다. 하지만, DEAP는 초매개변수 최적화 용도로 개발된 것은 아니다. 따라서, DEAP에 초매개변수 최적화를 적용하려면 별도의 구현이 좀 필요하다.
#
# 물론, 다행히도 DEAP와 scikit-learn을 결합해서 초매개변수 최적화 용도로 만들어 둔 라이브러리인 [sklearn-genetic-opt](https://sklearn-genetic-opt.readthedocs.io/en/stable/index.html)가 있다.
#
# 먼저, 초매개변수의 검색 공간을 정의하자.

# %%
from sklearn_genetic.space import Categorical, Integer, Continuous


search_space = {
    'n_estimators': Integer(5, 200), # 5 ~ 200 사이의 정수를 균일 분포 확률Uniformly Random로 뽑는다.
    'criterion': Categorical(['gini', 'entropy']), # 'gini' 와 'entropy'를 중 하나를 균일 분포 확률Uniformly Random로 뽑는다.
    'max_depth': Integer(3, 20), # 3 ~ 20 사이의 정수를 균일 분포 확률Uniformly Random로 뽑는다.
    'class_weight': Categorical(['balanced', 'balanced_subsample']), # 'balanced' 와 'balanced_subsample'를 중 하나를 균일 분포 확률Uniformly Random로 뽑는다.
    'min_samples_split': Continuous(0.01, 0.5), # 0.01 ~ 0.5 사이의 실수를 균일 분포 확률Uniformly Random로 뽑는다.
}

# %% [markdown]
# 그 다음에는 [sklearn.model_selection.GridSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html#sklearn.model_selection.GridSearchCV)나 [sklearn.model_selection.RandomizedSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html#sklearn.model_selection.RandomizedSearchCV)와 유사하게 [sklearn_genetic.GASearchCV](https://sklearn-genetic-opt.readthedocs.io/en/stable/api/gasearchcv.html)를 쓰면 된다.

# %%
from sklearn_genetic import GASearchCV
from sklearn.ensemble import RandomForestClassifier


optimizer = GASearchCV(
    estimator=RandomForestClassifier(random_state=42), # 초매개변수를 찾을 학습 모델,
    param_grid=search_space, # 초매개변수 검색 공간
    scoring='f1', # 성능 측정치; F1 score를 활용한다.
    criteria='max', # 성능 측정치를 최대화하는 방향으로 최적화를 수행한다.
    cv=3, # 내부 CV의 설정; 3를 넣을 시 Stratified 3-Fold CV를 수행한다. 또는, Cross-Validation 시간에 배웠던 Splitter 클래스들을 넣어도 된다.
    population_size=20, # 모집단의 개수를 의미한다.
    generations=10, # 몇 세대나 생성할지를 의미한다
    tournament_size=3, # 선택 시 몇 개체로 토너먼트를 할 지를 의미한다.
    crossover_probability=0.2, # 교배 시 각 개체가 가지고 있는 초매개변수가 교환될 확률을 의미한다.
    mutation_probability=0.1, # 자식 개체의 초매개변수가 변이할 확률을 의미한다.
)

optimizer.fit(X_train, y_train)
# Out:
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.453604	0.0290435  	0.519186   	0.420805
# 1  	9     	0.475616	0.0266384  	0.519186   	0.431452
# 2  	11    	0.499506	0.0219322  	0.519186   	0.455506
# 3  	16    	0.513135	0.00449957 	0.519186   	0.505694
# 4  	14    	0.516378	0.00156661 	0.519186   	0.515253
# 5  	12    	0.517791	0.0033353  	0.529294   	0.515253
# 6  	10    	0.521153	0.0044334  	0.532136   	0.516317
# 7  	14    	0.523273	0.00429845 	0.532136   	0.518566
# 8  	13    	0.529142	0.00292844 	0.532136   	0.523468
# 9  	12    	0.53119 	0.00125388 	0.532136   	0.529294
# 10 	10    	0.531947	0.000624312	0.532136   	0.529294
# GASearchCV(estimator=RandomForestClassifier(class_weight='balanced_subsample',
#                                             criterion='entropy', max_depth=20,
#                                             min_samples_split=0.026357045474641412,
#                                             n_estimators=94, random_state=42),
#            generations=10, mutation_probability=0.1,
#            param_grid={'class_weight': <sklearn_genetic.space.space.Categorical object at 0x79ef126825c0>,
#                        'criterion': <sklearn_genetic.space.space.Categorical object at 0x79ef12681f30>,
#                        'max_depth': <sklearn_genetic.space.space.Integer object at 0x79ef12683100>,
#                        'min_samples_split': <sklearn_genetic.space.space.Continuous object at 0x79ef126822c0>,
#                        'n_estimators': <sklearn_genetic.space.space.Integer object at 0x79ef12683640>},
#            population_size=20, return_train_score=True, scoring='f1')

# %% [markdown]
# 찾아낸 최적의 초매개변수와 검증 데이터셋에 대한 성능은 다음과 같다.

# %%
from sklearn.metrics import f1_score


y_pred = optimizer.best_estimator_.predict(X_test)

print(f'Best F1 Score: {optimizer.best_score_}')
print('Best Hyperparameters:')
print(optimizer.best_params_)
print(f'F1 Score on validation set: {f1_score(y_test, y_pred, pos_label=1)}')
# Out:
# Best F1 Score: 0.5321357087739744
# Best Hyperparameters:
# {'n_estimators': 94, 'criterion': 'entropy', 'max_depth': 20, 'class_weight': 'balanced_subsample', 'min_samples_split': 0.026357045474641412}
# F1 Score on validation set: 0.5286073123081217

# %% [markdown]
# ## Particle Swarm Optimization

# %% [markdown]
# Heuristic Search의 마지막으로, 무리 지성을 활용하는 Particle Swarm Optimization을 사용해보자. 다행히 PSO를 직접 구현할 필요 없이 [Optunity](https://optunity.readthedocs.io/en/latest/index.html)를 활용하면 된다. 하지만, 문제는 Optunity의 경우 오직 연속형 실수에 대해서만 초매개변수 탐색을 하도록 구현되어 있다는 것이다. 따라서, 목적 함수에 좀 수정이 필요하다. 먼저, 목적 함수부터 구현해보자.

# %%
import numpy as np
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold


def objective(n_estimators, criterion, max_depth, class_weight, min_samples_split):
    n_estimators = int(n_estimators) # 실수를 강제로 정수형으로 바꾼다.
    criterion = 'gini' if criterion < 0.5 else 'entropy' # 실수를 강제로 범주형 초매개변수로 바꾼다.
    max_depth = int(max_depth) # 실수를 강제로 정수형으로 바꾼다.
    class_weight = 'balanced' if class_weight < 0.5 else 'balanced_subsample' # 실수를 강제로 범주형 초매개변수로 바꾼다.

    splitter = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
    scores = []

    for I_train, I_test in splitter.split(X_train, y_train):
        X_inner_train, X_inner_test, y_inner_train, y_inner_test = X_train[I_train], X_train[I_test], y_train[I_train], y_train[I_test]
        model = RandomForestClassifier(
            random_state=42,
            n_estimators=n_estimators,
            criterion=criterion,
            max_depth=max_depth,
            class_weight=class_weight,
            min_samples_split=min_samples_split
        )
        model.fit(X_inner_train, y_inner_train)
        y_pred = model.predict(X_inner_test)
        f1 = f1_score(y_true=y_inner_test, y_pred=y_pred, pos_label=1)
        scores.append(f1)

    return np.mean(scores)

# %% [markdown]
# 위에서처럼 실수형 초매개변수를 강제로 정수형 초매개변수 또는 범주형 초매개변수로 바꿔주었다.
#
# 다음엔 초매개변수 검색 공간을 정의하자.

# %%
search_space = {
    'n_estimators': [5, 200], # 5 ~ 200 사이의 실수를 균일 분포 확률Uniformly Random로 뽑는다.
    'criterion': [0, 1], # 0 ~ 1 사이의 실수를 균일 분포 확률Uniformly Random로 뽑는다.
    'max_depth': [3, 20], # 3 ~ 20 사이의 실수를 균일 분포 확률Uniformly Random로 뽑는다.
    'class_weight': [0, 1], # 0 ~ 1 사이의 실수를 균일 분포 확률Uniformly Random로 뽑는다.
    'min_samples_split': [0.01, 0.5] # 0.01 ~ 0.5 사이의 실수를 균일 분포 확률Uniformly Random로 뽑는다.
}

# %% [markdown]
# 마지막으로, PSO를 통해 초매개변수 최적화를 해보자.

# %%
import optunity


best_params, logs, space = optunity.maximize(
    f=objective,
    num_evals=50, # PSO에서 위치 업데이트를 할 횟수
    solver_name='particle swarm', # Particle Swarm Optmiziation을 사용
    **search_space
)

# %%
best_params
# Out:
# {'n_estimators': 123.9717779124975,
#  'criterion': 0.8545833634311287,
#  'max_depth': 10.305683593750004,
#  'class_weight': 0.5657322328390989,
#  'min_samples_split': 0.04352480468750003}

# %% [markdown]
# PSO를 통해 찾아낸 최적의 초매개변수를 사용해서, 검증 데이터셋에 대한 성능을 확인해보자.

# %%
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier


model = RandomForestClassifier(
    random_state=42,
    class_weight='balanced_subsample',
    criterion='entropy',
    max_depth=int(10.305683593750004),
    min_samples_split=0.04352480468750003,
    n_estimators=int(123.9717779124975)
).fit(X_train, y_train)

y_pred = model.predict(X_test)
f1_score(y_test, y_pred, pos_label=1)
# Out:
# 0.5205252246026261

# %% [markdown]
# # Multi-Fidelity Optimization
# 이번엔 학습 모델의 Fidelity를 조정해서, 낮은 Fidelity Model에서는 많은 수의 초매개변수 후보를 탐색하고, 높은 Fidelity Model에서는 적은 수의 (검증된) 초매개변수 후보를 탐색하는 Multi-Fidelity Optimization을 해보자.

# %% [markdown]
# ## Successive Halving
#
# 가장 먼저 해볼 건 Succesive Halving이다. 수업 시간에 배운 다양한 MFO 기법의 기반이 되는 방법이니 만큼 여러 구현체가 존재한다. 게다가, 최근에는 scikit-learn에서도 Successive Halving 구현체를 제공한다! [sklearn.model_selection.GridSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html#sklearn.model_selection.GridSearchCV)와 [sklearn.model_selection.RandomizedSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html#sklearn.model_selection.RandomizedSearchCV)의 Successive Halving 버전인 [sklearn.model_selection.HalvingGridSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.HalvingGridSearchCV.html#sklearn.model_selection.HalvingGridSearchCV)와 [sklearn.model_selection.HalvingRandomSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.HalvingRandomSearchCV.html#sklearn.model_selection.HalvingRandomSearchCV)가 바로 그것이다.
#
# 지난 시간에 했던 GridSearchCV 또는 RandomizedSearchCV와 거의 유사하다. 먼저 초매개변수 검색 공간을 정의하자.

# %%
import scipy.stats as st


search_space = {
    'n_estimators': st.randint(5, 200), # 5 ~ 100 사이의 정수를 균일 분포 확률Uniformly Random로 뽑는다.
    'criterion': ['gini', 'entropy'], # 'gini' 와 'entropy'를 중 하나를 균일 분포 확률Uniformly Random로 뽑는다.
    'max_depth': st.randint(3, 20), # 3 ~ 20 사이의 정수를 균일 분포 확률Uniformly Random로 뽑는다.
    'class_weight': ['balanced', 'balanced_subsample'], # 'balanced' 와 'balanced_subsample'를 중 하나를 균일 분포 확률Uniformly Random로 뽑는다.
    'min_samples_split': st.truncnorm(a=0, b=0.5, loc=0.005, scale=0.01), # 평균은 0.005, 표준 편차는 0.01이, 최소값 0, 최대값 0.5인 정규 분포Normal Distribution에서 뽑는다.
}

# %% [markdown]
# 그럼 남은 건, HalvingRandomSearchCV를 RandomizedSearchCV와 동일하게 사용하는 것 뿐이다.

# %%
from sklearn.experimental import enable_halving_search_cv # 아직 Success Halving는 실험적 기능이라, 이를 먼저 실행해야 한다.
from sklearn.model_selection import HalvingRandomSearchCV
from sklearn.ensemble import RandomForestClassifier


optimizer = HalvingRandomSearchCV(
    estimator=RandomForestClassifier(random_state=42), # 초매개변수를 찾을 학습 모델,
    param_distributions=search_space, # 초매개변수 검색 공간,
    scoring='f1', # 성능 측정치; F1 score를 활용한다,
    cv=3, # 내부 CV의 설정; 3를 넣을 시 Stratified 3-Fold CV를 수행한다. 또는, Cross-Validation 시간에 배웠던 Splitter 클래스들을 넣어도 된다.
    n_jobs=-1, # 병렬로 실행할 작업의 개수를 의미한다. -1일 경우 모든 프로세서를 활용한다는 의미다.
    resource='n_samples', # 데이터의 수를 자원으로 사용한다.
    n_candidates=100, # 초기에 100개의 초매개변수 후보로 시작한다
    min_resources=20, # 초기에 20개의 데이터로 시작한다.
    factor=3, # 매 Halving 단계에서 감소시킬/증가시킬 초개매변수 후보/자원의 양을 의미한다; 3일 경우, 초매개변수 후보들은 1/3으로 줄이고, 자원의 양은 3배로 늘린다.
)

optimizer.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/joblib/externals/loky/backend/fork_exec.py:38: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid = os.fork()
# HalvingRandomSearchCV(cv=3, estimator=RandomForestClassifier(random_state=42),
#                       min_resources=20, n_candidates=100, n_jobs=-1,
#                       param_distributions={'class_weight': ['balanced',
#                                                             'balanced_subsample'],
#                                            'criterion': ['gini', 'entropy'],
#                                            'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x79eea7e67340>,
#                                            'min_samples_split': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x79eea7e67370>,
#                                            'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x79ef134264d0>},
#                       scoring='f1')

# %% [markdown]
# 찾아낸 최적의 초매개변수와 성능치는 다음과 같다:

# %%
from sklearn.metrics import f1_score


print(f'Best F1 Score: {optimizer.best_score_}')
print('Best Hyperparameters:')
print(optimizer.best_params_)
y_pred = optimizer.best_estimator_.predict(X_test)
print(f'F1 Score on validation set: {f1_score(y_test, y_pred, pos_label=1)}')
# Out:
# Best F1 Score: 0.47596104228369224
# Best Hyperparameters:
# {'class_weight': 'balanced_subsample', 'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 0.005339500060267382, 'n_estimators': 108}
# F1 Score on validation set: 0.508728899148752

# %% [markdown]
# Succesive Halving는 optuna에서도 제공한다. 사실, 이 이후에 할 Hyperband나 Bayesian Optimization and Hyperband를 하려면 optuna를 사용하는 게 더 좋다.
#
# 지난 시간에 했던 optuna 관련 내용 중 초매개변수를 추출하기 위한 공간을 정의하는 Sampler 인스턴스를 정의했던 것을 기억할 것이다. 이 외에도, optuna는 추출한 초매개변수 후보들을 줄이는 Pruner 인스턴스도 존재한다. 직관적으로, Successive Halving이나 Hyperband는 이미 초기에 추출했던 초매개변수 후보들을 **줄이는** Pruner의 일종임을 알 수 있을 것이다.
#
# optuna에서 Pruner가 동작하기 위해서는 다음과 같이 목적함수를 정의해야 한다.

# %%
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit
import optuna
import numpy as np


def objective(trial: optuna.Trial):
    n_estimators = trial.suggest_int('n_estimators', 5, 200)
    criterion = trial.suggest_categorical('criterion', ['gini', 'entropy'])
    max_depth = trial.suggest_int('max_depth', 3, 20)
    class_weight = trial.suggest_categorical('class_weight', ['balanced', 'balanced_subsample'])
    min_samples_split = trial.suggest_float('min_samples_split', 0.01, 0.05)

    # 여기서부터 Successive Halving에서 고려하는 자원양에 대한 학습 정도를 구현해야 한다.
    # scikit-learn은 알아서 자원양(데이터 수)를 증가시켜주었지만, optuna에서는 목적 함수내에서 구현할 필요가 있다.
    # 물론, 자유도 측면에서는 좋다.

    min_samples = 100 # 초기에 시작할 최소 샘플수
    factor = 3 # 매 반복마다 늘릴 샘플 수
    step = 0 # 반복 횟수

    while True:
        n_samples = min_samples * (factor ** step)
        is_completed = False
        # 매 반복마다 훈련에 사용할 데이터 양을 3배씩 늘려주자.
        if n_samples > len(X_train):
            X_resource, y_resource = X_train, y_train
            is_completed = True
        else:
            splitter = StratifiedShuffleSplit(n_splits=1, train_size=n_samples, random_state=42)
            I_resource, _ = next(splitter.split(X_train, y_train))
            X_resource, y_resource = X_train[I_resource], y_train[I_resource]

        # 이제 자원으로 사용할 데이터를 활용해 3-Fold CV를 하자
        splitter = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
        scores = []
        for I_train, I_test in splitter.split(X_resource, y_resource):
            X_inner_train, X_inner_test, y_inner_train, y_inner_test = X_resource[I_train], X_resource[I_test], y_resource[I_train], y_resource[I_test]
            model = RandomForestClassifier(
                random_state=42,
                n_estimators=n_estimators,
                criterion=criterion,
                max_depth=max_depth,
                class_weight=class_weight,
                min_samples_split=min_samples_split
            )
            model.fit(X_inner_train, y_inner_train)
            y_pred = model.predict(X_inner_test)
            f1 = f1_score(y_true=y_inner_test, y_pred=y_pred, pos_label=1)
            scores.append(f1)

        # 만약 모든 자원을 사용한 것이라면 Trial을 종료한다
        if is_completed:
            return np.mean(scores)
        # 그렇지 않다면, 중간 성능치 보고한다.
        # optuna는 여기서 보고한 성능치를 바탕으로,
        # 이 초매개변수의 제거 여부를 판단한다.
        else:
            trial.report(
                value=np.mean(scores),
                step=step
            )
        # 이 부분을 꼭 넣어줘야 Pruner가 이 Trial을 제거할 수 있다.
        if trial.should_prune():
            raise optuna.TrialPruned()
        step = step + 1

# %% [markdown]
# 그 다음엔, 아래처럼 [optuna.pruners.SuccessiveHalvingPruner](https://optuna.readthedocs.io/en/stable/reference/generated/optuna.pruners.SuccessiveHalvingPruner.html)를 pruner로 활용하면 된다,

# %%
import optuna
from optuna.samplers import RandomSampler
from optuna.pruners import SuccessiveHalvingPruner


study = optuna.create_study(
    sampler=RandomSampler(), # Successive Halving은 기본적으로 초기 초매개변수를 무작위로 찾기 때문에, RandomSampler를 사용한다.
    pruner=SuccessiveHalvingPruner(reduction_factor=3), # Successive Halving을 통해 초매개변수 후보들을 줄여나간다.
    direction='maximize', # F1 Score를 최대화하는 초매개변수를 찾는다
)

optuna.logging.set_verbosity(optuna.logging.WARNING) # 불필요한 로그는 보여주지 말자.

study.optimize(
    func=objective, # 목적 함수를 의미한다
    n_trials=50, # 탐색할 초매개변수들의 개수를 의미한다
    show_progress_bar=True # 표준 출력에 프로그레스 바를 보여준다.
)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
study.best_params
# Out:
# {'n_estimators': 93,
#  'criterion': 'entropy',
#  'max_depth': 16,
#  'class_weight': 'balanced',
#  'min_samples_split': 0.013542441252543495}

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score


model = RandomForestClassifier(
    random_state=42,
    **study.best_params
).fit(X_train, y_train)

y_pred = model.predict(X_test)
f1_score(y_test, y_pred, pos_label=1)
# Out:
# 0.5438494934876991

# %% [markdown]
# ## Hyperband

# %% [markdown]
# Hyperband는 간단하다. optuna에서 Pruner를 [optuna.pruners.HyperbandPruner](https://optuna.readthedocs.io/en/stable/reference/generated/optuna.pruners.HyperbandPruner.html)로 바꿔주기만 하면 된다.

# %%
import optuna
from optuna.samplers import RandomSampler
from optuna.pruners import HyperbandPruner


study = optuna.create_study(
    sampler=RandomSampler(), # Successive Halving은 기본적으로 초기 초매개변수를 무작위로 찾기 때문에, RandomSampler를 사용한다.
    pruner=HyperbandPruner(reduction_factor=3), # Successive Halving을 통해 초매개변수 후보들을 줄여나간다.
    direction='maximize', # F1 Score를 최대화하는 초매개변수를 찾는다
)

optuna.logging.set_verbosity(optuna.logging.WARNING) # 불필요한 로그는 보여주지 말자.

study.optimize(
    func=objective, # 목적 함수를 의미한다
    n_trials=50, # 탐색할 초매개변수들의 개수를 의미한다
    show_progress_bar=True # 표준 출력에 프로그레스 바를 보여준다.
)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
study.best_params
# Out:
# {'n_estimators': 60,
#  'criterion': 'gini',
#  'max_depth': 15,
#  'class_weight': 'balanced_subsample',
#  'min_samples_split': 0.01042357202241754}

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score


model = RandomForestClassifier(
    random_state=42,
    **study.best_params
).fit(X_train, y_train)

y_pred = model.predict(X_test)
f1_score(y_test, y_pred, pos_label=1)
# Out:
# 0.5441133931154181

# %% [markdown]
# ## Bayesian Optimization and Hyperband

# %% [markdown]
# 마지막으로는 Bayesian Optimization 방법을 활용해 초매개변수 후보들을 추출하고, Hyperband를 활용해 초매개변수 후보들을 줄여나가는 방법인 Bayesian Optimization and Hyperband를 활용해보겠다.
#
# 두 가지 방법이 있다. 하나는 optuna를 활용하는 것이고, 또 다른 하나는 HpBandSter를 활용하는 것이다. optuna를 활용하는 방법은 간단하게, sampler를 [optuna.samplers.TPESampler](https://optuna.readthedocs.io/en/stable/reference/samplers/generated/optuna.samplers.TPESampler.html)로, pruner를 [optuna.pruners.HyperbandPruner](https://optuna.readthedocs.io/en/stable/reference/generated/optuna.pruners.HyperbandPruner.html)로 설정하는 것이다. 단, 이 방법은 실제 BOHB를 제안한 원래 논문과는 좀 차이가 있다.

# %%
import optuna
from optuna.samplers import TPESampler
from optuna.pruners import HyperbandPruner


study = optuna.create_study(
    # Tree Parzen Estimator를 사용한다.
    sampler=TPESampler(
        multivariate=True # 초매개변수 각각이 독립적인 확률 분포를 이루는 게 아니라,
                          # 서로 다른 종류의 초매개변수가 서로 관련 있는 확률 분포를 이룬다고 설정해야 한다.
    ),
    pruner=HyperbandPruner(reduction_factor=3), # Successive Halving을 통해 초매개변수 후보들을 줄여나간다.
    direction='maximize', # F1 Score를 최대화하는 초매개변수를 찾는다
)

optuna.logging.set_verbosity(optuna.logging.WARNING) # 불필요한 로그는 보여주지 말자.

study.optimize(
    func=objective, # 목적 함수를 의미한다
    n_trials=50, # 탐색할 초매개변수들의 개수를 의미한다
    show_progress_bar=True # 표준 출력에 프로그레스 바를 보여준다.
)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
study.best_params
# Out:
# {'n_estimators': 43,
#  'criterion': 'gini',
#  'max_depth': 12,
#  'class_weight': 'balanced_subsample',
#  'min_samples_split': 0.010877274522118726}

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score


model = RandomForestClassifier(
    random_state=42,
    **study.best_params
).fit(X_train, y_train)

y_pred = model.predict(X_test)
f1_score(y_test, y_pred, pos_label=1)
# Out:
# 0.547667937811675

# %% [markdown]
# 실제 원본 논문과 동일하게 구현된 것은 [HpBandSter](https://github.com/automl/HpBandSter?tab=readme-ov-file)이다. 이를 써보려면 조금 복잡한 과정을 거쳐야 한다.
#
# 먼저, 아래와 같이 [hpbandster.core.worker.Worker](https://automl.github.io/HpBandSter/build/html/core/worker.html) 클래스를 구현해야 한다. 이 클래스에서 필수적으로 정의해야 할 것은  optuna 등에서 목적 함수로 활용되는 **compute**함수와 초매개변수 검색 공간을 의미하는 **get_configspace**이다.

# %%
import numpy as np
import ConfigSpace as cs
from hpbandster.core.worker import Worker
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit


class RFWorker(Worker):
    def __init__(self, X, y, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.X = X
        self.y = y

    # 초매개변수 검색 공간을 정의하는 함수다.
    # 주의할 점은 staticmethod로 정의되어야 하는 것이고,
    # dict 형이 아니라, ConfigSpace라는 라이브러리에서 활용하는 자료형을 써야 한다.
    # ConfigSpace 관련 내용은 다음 API로 확인하자: https://automl.github.io/ConfigSpace/main/api/hyperparameters.html
    @staticmethod
    def get_configspace():
        space = cs.ConfigurationSpace()
        n_estimators = cs.UniformIntegerHyperparameter(name='n_estimators', lower=5, upper=200)
        criterion = cs.UniformIntegerHyperparameter(name='criterion', lower=0, upper=1) # 범주형 초매개변수는 HpBandSter가 제대로 동작하지 않는 오류가 있으니 대신 정수로 바꿔줘야 한다
        max_depth = cs.UniformIntegerHyperparameter(name='max_depth', lower=3, upper=20)
        class_weight = cs.UniformIntegerHyperparameter(name='class_weight', lower=0, upper=1) # 범주형 초매개변수는 HpBandSter가 제대로 동작하지 않는 오류가 있으니 대신 정수로 바꿔줘야 한다
        min_samples_split = cs.UniformFloatHyperparameter(name='min_samples_split', lower=0.01, upper=0.05)

        space.add_hyperparameter(n_estimators)
        space.add_hyperparameter(criterion)
        space.add_hyperparameter(max_depth)
        space.add_hyperparameter(class_weight)
        space.add_hyperparameter(min_samples_split)

        return space

    # optuna의 목적 함수와 동일한 역할을 한다.
    def compute(self,
                config, # 초매개변수 후보가 있는 dict 자료형이다,
                budget, # Successive Halving 및 Hyperband에서 사용하는 자원을 의미한다.
                **kwargs
        ):
        # 추출된 초매개변수를 가져온다.
        n_estimators = config['n_estimators']
        criterion = ['gini', 'entropy'][config['criterion']]
        max_depth = config['max_depth']
        class_weight = ['balanced', 'balanced_subsample'][config['class_weight']]
        min_samples_split = config['min_samples_split']

        # 자원 양에 따라서 사용할 데이터의 양을 달리한다.
        if budget < 1.0:
            splitter = StratifiedShuffleSplit(n_splits=1, train_size=budget, random_state=42)
            I_resource, _ = next(splitter.split(self.X, self.y))
            X_resource, y_resource = self.X[I_resource], self.y[I_resource]
        else:
            X_resource, y_resource = self.X, self.y

        # 다음은 계속 했던 학습 모델 훈련 및 성능 추정이다.
        splitter = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
        scores = []

        for I_train, I_test in splitter.split(X_resource, y_resource):
            X_inner_train, X_inner_test, y_inner_train, y_inner_test = X_resource[I_train], X_resource[I_test], y_resource[I_train], y_resource[I_test]
            model = RandomForestClassifier(
                random_state=42,
                n_estimators=n_estimators,
                criterion=criterion,
                max_depth=max_depth,
                class_weight=class_weight,
                min_samples_split=min_samples_split
            )
            model.fit(X_inner_train, y_inner_train)
            y_pred = model.predict(X_inner_test)
            f1 = f1_score(y_true=y_inner_test, y_pred=y_pred, pos_label=1)
            scores.append(f1)

        # 마지막으로, 출력값은 무조건 loss와 info라는 key를 가진 dict 자료형이어야 한다.
        # 주의할점은 loss 값이 음수가 되면 제대로 학습이 되지 않는다.
        # 또한, loss에서 알 수 있듯이 HpBandSter는 성능치를 최소화하는 방향으로만 작동한다.
        # 따라서, 1에서 F1 Score을 빼주는 방식으로 loss를 구성했다.
        return {
            'loss': 1 - np.mean(scores),
            'info': config
        }

# %% [markdown]
# 이렇게 Worker를 구현했다면, 별도의 [hpbandster.core.nameserver.NameServer](https://automl.github.io/HpBandSter/build/html/core/nameserver.html)를 이용해 별도의 서버를 실행하고, 그 서버 내에서 위에 구현한 Worker를 실행해야 한다.

# %%
from hpbandster.core.nameserver import NameServer


RUN_ID = 'opt-rf-w-bohb' # 작업 ID를 의미한다.
HOST = 'localhost' # 서버의 주소
PORT = 9090 # 서버의 포트


# 아래와 같이 서버를 실행한다.
name_server = NameServer(run_id=RUN_ID, host=HOST, port=PORT)
name_server.start()

# 위에서 구현한 Worker를 위에 설정한 서버 상에서 실행한다.
worker = RFWorker(X=X_train, y=y_train, run_id=RUN_ID, nameserver=HOST, nameserver_port=PORT)
worker.run(background=True)

# %% [markdown]
# 마지막으로는, [hpbandster.optimizers.BOHB](https://automl.github.io/HpBandSter/build/html/optimizers/bohb.html)를 실행해서 최적의 매개변수를 찾는 것이다.

# %%
from hpbandster.optimizers import BOHB


bohb = BOHB(
    configspace = RFWorker.get_configspace(), # 검색 공간을 정의한다.
    run_id=RUN_ID,
    nameserver=HOST,
    nameserver_port=PORT,
    min_budget=0.01, # 최소 자원양을 의미한다.
    max_budget=1.0 # 최대 자원양을 의미한다.
)
result = bohb.run(n_iterations=50)

# %% [markdown]
# 다 끝났다면 BOHB와 서버를 종료한다.

# %%
bohb.shutdown(shutdown_workers=True)
name_server.shutdown()

# %% [markdown]
# 가장 최적의 초매개변수를 찾기 위해서는 일단 최적의 작업 ID를 가져와야 한다. 다음을 확인해보자.

# %%
best_trial_id = result.get_incumbent_id()
best_trial_id
# Out:
# (48, 0, 1)

# %% [markdown]
# 초매개변수들 중 이러한 ID를 가진 것을 가져오면 된다. 전체 초매개변수들은 다음에 저장되어 있다.

# %%
hyperparameters = result.get_id2config_mapping()
hyperparameters
# Out:
# {(0,
#   0,
#   0): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 17,
#    'min_samples_split': 0.027970181241246443,
#    'n_estimators': 127}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   1): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.027054761994011828,
#    'n_estimators': 106}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   2): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 20,
#    'min_samples_split': 0.010412808702363163,
#    'n_estimators': 68}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   3): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 19,
#    'min_samples_split': 0.015801038820204907,
#    'n_estimators': 38}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   4): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 7,
#    'min_samples_split': 0.03980010757298404,
#    'n_estimators': 167}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   5): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 9,
#    'min_samples_split': 0.03847808254218175,
#    'n_estimators': 148}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   6): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 18,
#    'min_samples_split': 0.03048136000543107,
#    'n_estimators': 196}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   7): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 5,
#    'min_samples_split': 0.020418185462223938,
#    'n_estimators': 87}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   8): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 13,
#    'min_samples_split': 0.028129908837315323,
#    'n_estimators': 146}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   9): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 18,
#    'min_samples_split': 0.03704447306176661,
#    'n_estimators': 115}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   10): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 14,
#    'min_samples_split': 0.023971399908098934,
#    'n_estimators': 150}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   11): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 14,
#    'min_samples_split': 0.04216583305874649,
#    'n_estimators': 172}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   12): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 4,
#    'min_samples_split': 0.04459950379983926,
#    'n_estimators': 105}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   13): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 7,
#    'min_samples_split': 0.03176879891131667,
#    'n_estimators': 23}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   14): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 12,
#    'min_samples_split': 0.04456684736430082,
#    'n_estimators': 161}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   15): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 6,
#    'min_samples_split': 0.04888269772046937,
#    'n_estimators': 167}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   16): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.043357800795531296,
#    'n_estimators': 169}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   17): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 9,
#    'min_samples_split': 0.03910822955317435,
#    'n_estimators': 188}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   18): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 5,
#    'min_samples_split': 0.022064569458178307,
#    'n_estimators': 104}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   19): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 6,
#    'min_samples_split': 0.018458687659497278,
#    'n_estimators': 107}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   20): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 7,
#    'min_samples_split': 0.03639822511672306,
#    'n_estimators': 52}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   21): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 5,
#    'min_samples_split': 0.03728304003258868,
#    'n_estimators': 177}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   22): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 13,
#    'min_samples_split': 0.021819002946746192,
#    'n_estimators': 50}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   23): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 11,
#    'min_samples_split': 0.04361334744910732,
#    'n_estimators': 47}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   24): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 3,
#    'min_samples_split': 0.031929787586503784,
#    'n_estimators': 44}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   25): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 3,
#    'min_samples_split': 0.019067220483919147,
#    'n_estimators': 81}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   26): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 3,
#    'min_samples_split': 0.02668761635074541,
#    'n_estimators': 14}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   27): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 4,
#    'min_samples_split': 0.010233381934966432,
#    'n_estimators': 12}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   28): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 3,
#    'min_samples_split': 0.03628676640366897,
#    'n_estimators': 11}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   29): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 3,
#    'min_samples_split': 0.031258912610095294,
#    'n_estimators': 52}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   30): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 6,
#    'min_samples_split': 0.023348054268457846,
#    'n_estimators': 68}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   31): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 8,
#    'min_samples_split': 0.02443291211079792,
#    'n_estimators': 93}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   32): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 6,
#    'min_samples_split': 0.01633759642605113,
#    'n_estimators': 16}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   33): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 18,
#    'min_samples_split': 0.016145026759602936,
#    'n_estimators': 114}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   34): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 6,
#    'min_samples_split': 0.012636343966768127,
#    'n_estimators': 9}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   35): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 3,
#    'min_samples_split': 0.04494916185441685,
#    'n_estimators': 44}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   36): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 7,
#    'min_samples_split': 0.04492214596911581,
#    'n_estimators': 20}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   37): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 3,
#    'min_samples_split': 0.02622072841379889,
#    'n_estimators': 11}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   38): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 20,
#    'min_samples_split': 0.027544295708385243,
#    'n_estimators': 172}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   39): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 4,
#    'min_samples_split': 0.044183912080182595,
#    'n_estimators': 55}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   40): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 3,
#    'min_samples_split': 0.04679252506884412,
#    'n_estimators': 55}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   41): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 4,
#    'min_samples_split': 0.04471591831594865,
#    'n_estimators': 53}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   42): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 12,
#    'min_samples_split': 0.024506291036494716,
#    'n_estimators': 157}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   43): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 3,
#    'min_samples_split': 0.03411943886612449,
#    'n_estimators': 47}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   44): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 3,
#    'min_samples_split': 0.04923408354208328,
#    'n_estimators': 43}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   45): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 3,
#    'min_samples_split': 0.04341467623018229,
#    'n_estimators': 40}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   46): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 3,
#    'min_samples_split': 0.04085220806151622,
#    'n_estimators': 45}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   47): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 3,
#    'min_samples_split': 0.03696270672113714,
#    'n_estimators': 39}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   48): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 4,
#    'min_samples_split': 0.01690093287394765,
#    'n_estimators': 177}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   49): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 14,
#    'min_samples_split': 0.022249736809308508,
#    'n_estimators': 169}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   50): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 3,
#    'min_samples_split': 0.03449561823619534,
#    'n_estimators': 56}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   51): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 3,
#    'min_samples_split': 0.03215022419968627,
#    'n_estimators': 54}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   52): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 12,
#    'min_samples_split': 0.03127905749215304,
#    'n_estimators': 200}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   53): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 4,
#    'min_samples_split': 0.04829058625389495,
#    'n_estimators': 56}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   54): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 3,
#    'min_samples_split': 0.04943304042012429,
#    'n_estimators': 49}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   55): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 17,
#    'min_samples_split': 0.031661611300878224,
#    'n_estimators': 60}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   56): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 3,
#    'min_samples_split': 0.03566861138001049,
#    'n_estimators': 49}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   57): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 3,
#    'min_samples_split': 0.030840820827623003,
#    'n_estimators': 54}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   58): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 4,
#    'min_samples_split': 0.03856267866064992,
#    'n_estimators': 54}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   59): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 4,
#    'min_samples_split': 0.0396489708589405,
#    'n_estimators': 54}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   60): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 3,
#    'min_samples_split': 0.02844796111508626,
#    'n_estimators': 53}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   61): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 4,
#    'min_samples_split': 0.04310893173612128,
#    'n_estimators': 53}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   62): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 13,
#    'min_samples_split': 0.014412321459286927,
#    'n_estimators': 123}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   63): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 12,
#    'min_samples_split': 0.046123781876083715,
#    'n_estimators': 98}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   64): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 12,
#    'min_samples_split': 0.04082397022375429,
#    'n_estimators': 159}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   65): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 4,
#    'min_samples_split': 0.04578237526060778,
#    'n_estimators': 55}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   66): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 4,
#    'min_samples_split': 0.041730080116791274,
#    'n_estimators': 56}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   67): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 10,
#    'min_samples_split': 0.012139238330060857,
#    'n_estimators': 86}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   68): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 15,
#    'min_samples_split': 0.03749346422600626,
#    'n_estimators': 15}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   69): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 16,
#    'min_samples_split': 0.03793682340594468,
#    'n_estimators': 26}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   70): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 5,
#    'min_samples_split': 0.03808922837900411,
#    'n_estimators': 88}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   71): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 13,
#    'min_samples_split': 0.020013599088317836,
#    'n_estimators': 50}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   72): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 4,
#    'min_samples_split': 0.04000363409660834,
#    'n_estimators': 52}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   73): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 4,
#    'min_samples_split': 0.036430016049821136,
#    'n_estimators': 51}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   74): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 7,
#    'min_samples_split': 0.04248273954705439,
#    'n_estimators': 53}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   75): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 12,
#    'min_samples_split': 0.02817102981136043,
#    'n_estimators': 127}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   76): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 6,
#    'min_samples_split': 0.025926569660967333,
#    'n_estimators': 85}, 'config_info': {'model_based_pick': False}},
#  (0,
#   0,
#   77): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 3,
#    'min_samples_split': 0.027898692335087724,
#    'n_estimators': 53}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   78): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 3,
#    'min_samples_split': 0.02631507290983536,
#    'n_estimators': 55}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   79): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 3,
#    'min_samples_split': 0.035653069679096976,
#    'n_estimators': 50}, 'config_info': {'model_based_pick': True}},
#  (0,
#   0,
#   80): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 4,
#    'min_samples_split': 0.0360965934413873,
#    'n_estimators': 52}, 'config_info': {'model_based_pick': True}},
#  (1,
#   0,
#   0): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 13,
#    'min_samples_split': 0.03658694737041497,
#    'n_estimators': 20}, 'config_info': {'model_based_pick': True}},
#  (1,
#   0,
#   1): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 8,
#    'min_samples_split': 0.032703216422835885,
#    'n_estimators': 120}, 'config_info': {'model_based_pick': True}},
#  (1,
#   0,
#   2): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 11,
#    'min_samples_split': 0.024934934225392162,
#    'n_estimators': 149}, 'config_info': {'model_based_pick': True}},
#  (1,
#   0,
#   3): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 11,
#    'min_samples_split': 0.047579992866081035,
#    'n_estimators': 128}, 'config_info': {'model_based_pick': False}},
#  (1,
#   0,
#   4): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 12,
#    'min_samples_split': 0.049613318781858616,
#    'n_estimators': 131}, 'config_info': {'model_based_pick': True}},
#  (1,
#   0,
#   5): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 19,
#    'min_samples_split': 0.041551326365417966,
#    'n_estimators': 130}, 'config_info': {'model_based_pick': True}},
#  (1,
#   0,
#   6): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 17,
#    'min_samples_split': 0.04783540635246776,
#    'n_estimators': 15}, 'config_info': {'model_based_pick': True}},
#  (1,
#   0,
#   7): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 8,
#    'min_samples_split': 0.01402615687107995,
#    'n_estimators': 132}, 'config_info': {'model_based_pick': False}},
#  (1,
#   0,
#   8): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 7,
#    'min_samples_split': 0.04734555764868789,
#    'n_estimators': 198}, 'config_info': {'model_based_pick': True}},
#  (1,
#   0,
#   9): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 15,
#    'min_samples_split': 0.04426260935562919,
#    'n_estimators': 8}, 'config_info': {'model_based_pick': True}},
#  (1,
#   0,
#   10): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 6,
#    'min_samples_split': 0.04551818345614392,
#    'n_estimators': 93}, 'config_info': {'model_based_pick': True}},
#  (1,
#   0,
#   11): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 6,
#    'min_samples_split': 0.04556249782469905,
#    'n_estimators': 167}, 'config_info': {'model_based_pick': True}},
#  (1,
#   0,
#   12): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 4,
#    'min_samples_split': 0.04617665477192399,
#    'n_estimators': 167}, 'config_info': {'model_based_pick': True}},
#  (1,
#   0,
#   13): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 16,
#    'min_samples_split': 0.03154812634399031,
#    'n_estimators': 76}, 'config_info': {'model_based_pick': False}},
#  (1,
#   0,
#   14): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 8,
#    'min_samples_split': 0.047316348091790764,
#    'n_estimators': 186}, 'config_info': {'model_based_pick': True}},
#  (1,
#   0,
#   15): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 16,
#    'min_samples_split': 0.02438473284449535,
#    'n_estimators': 14}, 'config_info': {'model_based_pick': False}},
#  (1,
#   0,
#   16): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 5,
#    'min_samples_split': 0.038662442420912095,
#    'n_estimators': 14}, 'config_info': {'model_based_pick': False}},
#  (1,
#   0,
#   17): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 7,
#    'min_samples_split': 0.04735836860303491,
#    'n_estimators': 89}, 'config_info': {'model_based_pick': True}},
#  (1,
#   0,
#   18): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 17,
#    'min_samples_split': 0.03746484998097812,
#    'n_estimators': 64}, 'config_info': {'model_based_pick': False}},
#  (1,
#   0,
#   19): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 13,
#    'min_samples_split': 0.04875625979456282,
#    'n_estimators': 146}, 'config_info': {'model_based_pick': True}},
#  (1,
#   0,
#   20): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 12,
#    'min_samples_split': 0.021031824071835282,
#    'n_estimators': 196}, 'config_info': {'model_based_pick': False}},
#  (1,
#   0,
#   21): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 11,
#    'min_samples_split': 0.04857490238487205,
#    'n_estimators': 109}, 'config_info': {'model_based_pick': False}},
#  (1,
#   0,
#   22): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 17,
#    'min_samples_split': 0.03663642959993328,
#    'n_estimators': 53}, 'config_info': {'model_based_pick': False}},
#  (1,
#   0,
#   23): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 9,
#    'min_samples_split': 0.02015024492917481,
#    'n_estimators': 193}, 'config_info': {'model_based_pick': False}},
#  (1,
#   0,
#   24): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 12,
#    'min_samples_split': 0.04873516665682456,
#    'n_estimators': 190}, 'config_info': {'model_based_pick': True}},
#  (1,
#   0,
#   25): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 5,
#    'min_samples_split': 0.04888754329816315,
#    'n_estimators': 180}, 'config_info': {'model_based_pick': True}},
#  (1,
#   0,
#   26): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 14,
#    'min_samples_split': 0.04833696797948445,
#    'n_estimators': 77}, 'config_info': {'model_based_pick': True}},
#  (2,
#   0,
#   0): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 20,
#    'min_samples_split': 0.012804700616789582,
#    'n_estimators': 38}, 'config_info': {'model_based_pick': True}},
#  (2,
#   0,
#   1): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 16,
#    'min_samples_split': 0.02026282955796551,
#    'n_estimators': 100}, 'config_info': {'model_based_pick': False}},
#  (2,
#   0,
#   2): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 19,
#    'min_samples_split': 0.015912945737047535,
#    'n_estimators': 125}, 'config_info': {'model_based_pick': False}},
#  (2,
#   0,
#   3): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 12,
#    'min_samples_split': 0.0382136065280343,
#    'n_estimators': 79}, 'config_info': {'model_based_pick': False}},
#  (2,
#   0,
#   4): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 17,
#    'min_samples_split': 0.014223120226788347,
#    'n_estimators': 185}, 'config_info': {'model_based_pick': True}},
#  (2,
#   0,
#   5): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 15,
#    'min_samples_split': 0.04396838885329482,
#    'n_estimators': 158}, 'config_info': {'model_based_pick': False}},
#  (2,
#   0,
#   6): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 17,
#    'min_samples_split': 0.01727667466280182,
#    'n_estimators': 21}, 'config_info': {'model_based_pick': False}},
#  (2,
#   0,
#   7): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 17,
#    'min_samples_split': 0.01076733175833872,
#    'n_estimators': 23}, 'config_info': {'model_based_pick': True}},
#  (2,
#   0,
#   8): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 17,
#    'min_samples_split': 0.012390832002449967,
#    'n_estimators': 41}, 'config_info': {'model_based_pick': True}},
#  (3,
#   0,
#   0): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 7,
#    'min_samples_split': 0.022438920865316528,
#    'n_estimators': 157}, 'config_info': {'model_based_pick': False}},
#  (3,
#   0,
#   1): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.012960134163184311,
#    'n_estimators': 24}, 'config_info': {'model_based_pick': True}},
#  (3,
#   0,
#   2): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 16,
#    'min_samples_split': 0.012899782680243945,
#    'n_estimators': 14}, 'config_info': {'model_based_pick': True}},
#  (3,
#   0,
#   3): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 18,
#    'min_samples_split': 0.04195038276050886,
#    'n_estimators': 34}, 'config_info': {'model_based_pick': False}},
#  (3,
#   0,
#   4): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.019419183731086757,
#    'n_estimators': 107}, 'config_info': {'model_based_pick': True}},
#  (3,
#   0,
#   5): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.010650241354007882,
#    'n_estimators': 156}, 'config_info': {'model_based_pick': True}},
#  (4,
#   0,
#   0): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 19,
#    'min_samples_split': 0.012713986932545279,
#    'n_estimators': 175}, 'config_info': {'model_based_pick': True}},
#  (4,
#   0,
#   1): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 5,
#    'min_samples_split': 0.043021111385323295,
#    'n_estimators': 14}, 'config_info': {'model_based_pick': False}},
#  (4,
#   0,
#   2): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.017621935082830584,
#    'n_estimators': 159}, 'config_info': {'model_based_pick': True}},
#  (4,
#   0,
#   3): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 19,
#    'min_samples_split': 0.012672878862716782,
#    'n_estimators': 174}, 'config_info': {'model_based_pick': True}},
#  (4,
#   0,
#   4): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.01313732489704058,
#    'n_estimators': 27}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   0): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 17,
#    'min_samples_split': 0.017881980401551888,
#    'n_estimators': 114}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   1): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.011218166180935431,
#    'n_estimators': 143}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   2): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.011789040486056161,
#    'n_estimators': 117}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   3): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 11,
#    'min_samples_split': 0.011853684190107062,
#    'n_estimators': 111}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   4): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 18,
#    'min_samples_split': 0.014981495666546392,
#    'n_estimators': 66}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   5): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 10,
#    'min_samples_split': 0.04021592119993107,
#    'n_estimators': 189}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   6): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 18,
#    'min_samples_split': 0.010167041087837624,
#    'n_estimators': 77}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   7): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 20,
#    'min_samples_split': 0.013952921534115651,
#    'n_estimators': 46}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   8): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 3,
#    'min_samples_split': 0.04634141800003353,
#    'n_estimators': 69}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   9): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.017817646248160394,
#    'n_estimators': 156}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   10): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 18,
#    'min_samples_split': 0.011736148967728248,
#    'n_estimators': 185}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   11): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 4,
#    'min_samples_split': 0.010895523869170951,
#    'n_estimators': 14}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   12): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.012861521736840732,
#    'n_estimators': 184}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   13): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 20,
#    'min_samples_split': 0.011452258032976998,
#    'n_estimators': 80}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   14): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 20,
#    'min_samples_split': 0.014554841379747245,
#    'n_estimators': 195}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   15): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 19,
#    'min_samples_split': 0.011969311445553929,
#    'n_estimators': 90}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   16): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 16,
#    'min_samples_split': 0.031257992182945664,
#    'n_estimators': 150}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   17): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 15,
#    'min_samples_split': 0.013090090095113643,
#    'n_estimators': 186}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   18): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.015034100942595328,
#    'n_estimators': 176}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   19): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 18,
#    'min_samples_split': 0.011304209324655017,
#    'n_estimators': 73}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   20): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 20,
#    'min_samples_split': 0.011882996966111647,
#    'n_estimators': 16}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   21): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.03285035110208642,
#    'n_estimators': 38}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   22): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 19,
#    'min_samples_split': 0.013023078478734459,
#    'n_estimators': 61}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   23): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 16,
#    'min_samples_split': 0.01477663798934294,
#    'n_estimators': 123}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   24): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 19,
#    'min_samples_split': 0.019809102871989934,
#    'n_estimators': 179}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   25): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 17,
#    'min_samples_split': 0.01463685792864285,
#    'n_estimators': 195}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   26): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 8,
#    'min_samples_split': 0.026605587821860045,
#    'n_estimators': 158}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   27): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 11,
#    'min_samples_split': 0.012838650212510249,
#    'n_estimators': 17}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   28): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 14,
#    'min_samples_split': 0.03937797118778829,
#    'n_estimators': 149}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   29): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 19,
#    'min_samples_split': 0.013928717017614877,
#    'n_estimators': 161}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   30): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 19,
#    'min_samples_split': 0.012335172465754815,
#    'n_estimators': 174}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   31): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 18,
#    'min_samples_split': 0.011525689988201686,
#    'n_estimators': 25}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   32): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 3,
#    'min_samples_split': 0.022118278044160375,
#    'n_estimators': 162}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   33): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.017154712184674056,
#    'n_estimators': 48}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   34): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.014738248087385844,
#    'n_estimators': 151}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   35): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 19,
#    'min_samples_split': 0.019573732523224325,
#    'n_estimators': 195}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   36): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.012196775271269817,
#    'n_estimators': 177}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   37): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.014077368266403012,
#    'n_estimators': 47}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   38): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.011402705629160263,
#    'n_estimators': 145}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   39): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 20,
#    'min_samples_split': 0.010217184614272252,
#    'n_estimators': 22}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   40): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.014230673339505331,
#    'n_estimators': 160}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   41): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 19,
#    'min_samples_split': 0.012216524848428308,
#    'n_estimators': 110}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   42): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 20,
#    'min_samples_split': 0.010510338379796934,
#    'n_estimators': 60}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   43): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 14,
#    'min_samples_split': 0.010426038570245866,
#    'n_estimators': 77}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   44): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 18,
#    'min_samples_split': 0.016381882894467764,
#    'n_estimators': 192}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   45): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 20,
#    'min_samples_split': 0.011758379198397177,
#    'n_estimators': 70}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   46): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.012239353244451169,
#    'n_estimators': 41}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   47): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 19,
#    'min_samples_split': 0.014117569748454652,
#    'n_estimators': 179}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   48): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 13,
#    'min_samples_split': 0.024472282465627618,
#    'n_estimators': 36}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   49): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.013837244175580082,
#    'n_estimators': 179}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   50): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.012046602656861418,
#    'n_estimators': 198}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   51): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.016357623931003387,
#    'n_estimators': 138}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   52): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.011058644636522213,
#    'n_estimators': 46}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   53): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 19,
#    'min_samples_split': 0.011480261567358895,
#    'n_estimators': 155}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   54): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 3,
#    'min_samples_split': 0.04566177742456257,
#    'n_estimators': 89}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   55): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 20,
#    'min_samples_split': 0.011967057159190274,
#    'n_estimators': 14}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   56): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.01294364209062522,
#    'n_estimators': 174}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   57): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 19,
#    'min_samples_split': 0.014049690199960805,
#    'n_estimators': 172}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   58): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 17,
#    'min_samples_split': 0.031079566954858445,
#    'n_estimators': 193}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   59): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 3,
#    'min_samples_split': 0.04983739984296996,
#    'n_estimators': 91}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   60): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 6,
#    'min_samples_split': 0.027458597483013672,
#    'n_estimators': 67}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   61): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 5,
#    'min_samples_split': 0.04495858578042945,
#    'n_estimators': 43}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   62): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 13,
#    'min_samples_split': 0.028133226592963807,
#    'n_estimators': 191}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   63): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 16,
#    'min_samples_split': 0.0481456866026847,
#    'n_estimators': 64}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   64): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 20,
#    'min_samples_split': 0.012621688857883132,
#    'n_estimators': 51}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   65): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 15,
#    'min_samples_split': 0.042277178324203225,
#    'n_estimators': 52}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   66): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 11,
#    'min_samples_split': 0.02604579151067353,
#    'n_estimators': 45}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   67): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 19,
#    'min_samples_split': 0.010471210597815772,
#    'n_estimators': 103}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   68): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.011933335522836696,
#    'n_estimators': 144}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   69): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 17,
#    'min_samples_split': 0.011630399584224793,
#    'n_estimators': 8}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   70): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.016238605628717383,
#    'n_estimators': 190}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   71): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 20,
#    'min_samples_split': 0.013366728913793167,
#    'n_estimators': 59}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   72): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 12,
#    'min_samples_split': 0.010020480216521906,
#    'n_estimators': 44}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   73): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 4,
#    'min_samples_split': 0.011562040715846704,
#    'n_estimators': 109}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   74): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 20,
#    'min_samples_split': 0.016585521919447656,
#    'n_estimators': 11}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   75): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 5,
#    'min_samples_split': 0.047486912114817974,
#    'n_estimators': 139}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   76): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 19,
#    'min_samples_split': 0.045381305514630585,
#    'n_estimators': 18}, 'config_info': {'model_based_pick': False}},
#  (5,
#   0,
#   77): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.011175934521817447,
#    'n_estimators': 188}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   78): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.01002180630815931,
#    'n_estimators': 146}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   79): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.010659185686706462,
#    'n_estimators': 147}, 'config_info': {'model_based_pick': True}},
#  (5,
#   0,
#   80): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 17,
#    'min_samples_split': 0.012310688348465418,
#    'n_estimators': 187}, 'config_info': {'model_based_pick': True}},
#  (6,
#   0,
#   0): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 12,
#    'min_samples_split': 0.010354836664268282,
#    'n_estimators': 174}, 'config_info': {'model_based_pick': False}},
#  (6,
#   0,
#   1): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 18,
#    'min_samples_split': 0.014193829701119688,
#    'n_estimators': 40}, 'config_info': {'model_based_pick': True}},
#  (6,
#   0,
#   2): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.011327688284177266,
#    'n_estimators': 50}, 'config_info': {'model_based_pick': True}},
#  (6,
#   0,
#   3): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 14,
#    'min_samples_split': 0.010217119772599462,
#    'n_estimators': 151}, 'config_info': {'model_based_pick': False}},
#  (6,
#   0,
#   4): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.010066844091965649,
#    'n_estimators': 61}, 'config_info': {'model_based_pick': True}},
#  (6,
#   0,
#   5): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.0105154291606231,
#    'n_estimators': 92}, 'config_info': {'model_based_pick': True}},
#  (6,
#   0,
#   6): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 7,
#    'min_samples_split': 0.03263273398696931,
#    'n_estimators': 125}, 'config_info': {'model_based_pick': False}},
#  (6,
#   0,
#   7): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 9,
#    'min_samples_split': 0.015129932624078642,
#    'n_estimators': 184}, 'config_info': {'model_based_pick': False}},
#  (6,
#   0,
#   8): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 19,
#    'min_samples_split': 0.01826132374892834,
#    'n_estimators': 56}, 'config_info': {'model_based_pick': False}},
#  (6,
#   0,
#   9): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.01207587019923031,
#    'n_estimators': 196}, 'config_info': {'model_based_pick': False}},
#  (6,
#   0,
#   10): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 19,
#    'min_samples_split': 0.013562261599908781,
#    'n_estimators': 7}, 'config_info': {'model_based_pick': True}},
#  (6,
#   0,
#   11): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 18,
#    'min_samples_split': 0.010619253333526646,
#    'n_estimators': 22}, 'config_info': {'model_based_pick': True}},
#  (6,
#   0,
#   12): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.011656716876275066,
#    'n_estimators': 12}, 'config_info': {'model_based_pick': True}},
#  (6,
#   0,
#   13): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.011543759547190667,
#    'n_estimators': 17}, 'config_info': {'model_based_pick': True}},
#  (6,
#   0,
#   14): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.012311446849182808,
#    'n_estimators': 97}, 'config_info': {'model_based_pick': True}},
#  (6,
#   0,
#   15): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 18,
#    'min_samples_split': 0.013216588829677817,
#    'n_estimators': 7}, 'config_info': {'model_based_pick': True}},
#  (6,
#   0,
#   16): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.01683966440922812,
#    'n_estimators': 40}, 'config_info': {'model_based_pick': True}},
#  (6,
#   0,
#   17): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 17,
#    'min_samples_split': 0.02075864011732455,
#    'n_estimators': 191}, 'config_info': {'model_based_pick': False}},
#  (6,
#   0,
#   18): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.010983296609661146,
#    'n_estimators': 20}, 'config_info': {'model_based_pick': True}},
#  (6,
#   0,
#   19): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 11,
#    'min_samples_split': 0.0397361126830212,
#    'n_estimators': 124}, 'config_info': {'model_based_pick': False}},
#  (6,
#   0,
#   20): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 20,
#    'min_samples_split': 0.011839143997241305,
#    'n_estimators': 62}, 'config_info': {'model_based_pick': True}},
#  (6,
#   0,
#   21): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.011712586490244408,
#    'n_estimators': 117}, 'config_info': {'model_based_pick': True}},
#  (6,
#   0,
#   22): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 8,
#    'min_samples_split': 0.022201001320283645,
#    'n_estimators': 58}, 'config_info': {'model_based_pick': False}},
#  (6,
#   0,
#   23): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.04678515203697937,
#    'n_estimators': 64}, 'config_info': {'model_based_pick': False}},
#  (6,
#   0,
#   24): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 19,
#    'min_samples_split': 0.010092273898601574,
#    'n_estimators': 47}, 'config_info': {'model_based_pick': True}},
#  (6,
#   0,
#   25): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.010812755012054748,
#    'n_estimators': 64}, 'config_info': {'model_based_pick': True}},
#  (6,
#   0,
#   26): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.011649584888767696,
#    'n_estimators': 185}, 'config_info': {'model_based_pick': True}},
#  (7,
#   0,
#   0): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.011265668738440867,
#    'n_estimators': 56}, 'config_info': {'model_based_pick': True}},
#  (7,
#   0,
#   1): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.010161350663771654,
#    'n_estimators': 111}, 'config_info': {'model_based_pick': True}},
#  (7,
#   0,
#   2): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 18,
#    'min_samples_split': 0.012582210277914063,
#    'n_estimators': 186}, 'config_info': {'model_based_pick': False}},
#  (7,
# ...
#   25): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 19,
#    'min_samples_split': 0.01045594124724503,
#    'n_estimators': 176}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   26): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 20,
#    'min_samples_split': 0.010205923041063445,
#    'n_estimators': 179}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   27): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 10,
#    'min_samples_split': 0.04060955730697303,
#    'n_estimators': 119}, 'config_info': {'model_based_pick': False}},
#  (35,
#   0,
#   28): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 19,
#    'min_samples_split': 0.010234936078634604,
#    'n_estimators': 179}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   29): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 19,
#    'min_samples_split': 0.010192888265607348,
#    'n_estimators': 179}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   30): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 18,
#    'min_samples_split': 0.010441509054506972,
#    'n_estimators': 178}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   31): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 15,
#    'min_samples_split': 0.0442011225856368,
#    'n_estimators': 23}, 'config_info': {'model_based_pick': False}},
#  (35,
#   0,
#   32): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 18,
#    'min_samples_split': 0.010149760291233913,
#    'n_estimators': 177}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   33): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 4,
#    'min_samples_split': 0.02101023997544544,
#    'n_estimators': 96}, 'config_info': {'model_based_pick': False}},
#  (35,
#   0,
#   34): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 19,
#    'min_samples_split': 0.0100300752072692,
#    'n_estimators': 182}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   35): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.010482231891633333,
#    'n_estimators': 179}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   36): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 20,
#    'min_samples_split': 0.010181843501332615,
#    'n_estimators': 180}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   37): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 6,
#    'min_samples_split': 0.017412482044422157,
#    'n_estimators': 189}, 'config_info': {'model_based_pick': False}},
#  (35,
#   0,
#   38): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 19,
#    'min_samples_split': 0.04757949337987464,
#    'n_estimators': 140}, 'config_info': {'model_based_pick': False}},
#  (35,
#   0,
#   39): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.010104747052743569,
#    'n_estimators': 178}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   40): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 20,
#    'min_samples_split': 0.01066653597410315,
#    'n_estimators': 183}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   41): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 19,
#    'min_samples_split': 0.010389787336945663,
#    'n_estimators': 186}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   42): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 20,
#    'min_samples_split': 0.010300564293494076,
#    'n_estimators': 177}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   43): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 19,
#    'min_samples_split': 0.02919937123416625,
#    'n_estimators': 22}, 'config_info': {'model_based_pick': False}},
#  (35,
#   0,
#   44): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 20,
#    'min_samples_split': 0.021919096534887668,
#    'n_estimators': 146}, 'config_info': {'model_based_pick': False}},
#  (35,
#   0,
#   45): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 18,
#    'min_samples_split': 0.010505798853205453,
#    'n_estimators': 177}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   46): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 18,
#    'min_samples_split': 0.01056020131257345,
#    'n_estimators': 180}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   47): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.010313157512323303,
#    'n_estimators': 182}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   48): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 12,
#    'min_samples_split': 0.026658709860768973,
#    'n_estimators': 124}, 'config_info': {'model_based_pick': False}},
#  (35,
#   0,
#   49): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 14,
#    'min_samples_split': 0.029520470928449248,
#    'n_estimators': 38}, 'config_info': {'model_based_pick': False}},
#  (35,
#   0,
#   50): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.010382235630233787,
#    'n_estimators': 181}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   51): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 15,
#    'min_samples_split': 0.019333914330301055,
#    'n_estimators': 125}, 'config_info': {'model_based_pick': False}},
#  (35,
#   0,
#   52): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.01033869201555592,
#    'n_estimators': 180}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   53): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 18,
#    'min_samples_split': 0.010226911524233434,
#    'n_estimators': 180}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   54): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.010505135655027188,
#    'n_estimators': 179}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   55): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 18,
#    'min_samples_split': 0.010358106195577046,
#    'n_estimators': 180}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   56): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 20,
#    'min_samples_split': 0.010215165693919967,
#    'n_estimators': 180}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   57): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 10,
#    'min_samples_split': 0.03858411503060715,
#    'n_estimators': 140}, 'config_info': {'model_based_pick': False}},
#  (35,
#   0,
#   58): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 20,
#    'min_samples_split': 0.010137651929882507,
#    'n_estimators': 178}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   59): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 3,
#    'min_samples_split': 0.02470005076615811,
#    'n_estimators': 47}, 'config_info': {'model_based_pick': False}},
#  (35,
#   0,
#   60): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 3,
#    'min_samples_split': 0.018077442384038,
#    'n_estimators': 36}, 'config_info': {'model_based_pick': False}},
#  (35,
#   0,
#   61): {'config': {'class_weight': 0,
#    'criterion': 0,
#    'max_depth': 5,
#    'min_samples_split': 0.04132062830909993,
#    'n_estimators': 99}, 'config_info': {'model_based_pick': False}},
#  (35,
#   0,
#   62): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 18,
#    'min_samples_split': 0.037298980742356436,
#    'n_estimators': 24}, 'config_info': {'model_based_pick': False}},
#  (35,
#   0,
#   63): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 20,
#    'min_samples_split': 0.010375947776139743,
#    'n_estimators': 179}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   64): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.010262621033805786,
#    'n_estimators': 179}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   65): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 17,
#    'min_samples_split': 0.01040343411738634,
#    'n_estimators': 176}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   66): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.01041095124806852,
#    'n_estimators': 178}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   67): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 17,
#    'min_samples_split': 0.0106657222628756,
#    'n_estimators': 176}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   68): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 18,
#    'min_samples_split': 0.010429035076770388,
#    'n_estimators': 181}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   69): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 18,
#    'min_samples_split': 0.01034853607657803,
#    'n_estimators': 180}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   70): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 9,
#    'min_samples_split': 0.04942393292899056,
#    'n_estimators': 109}, 'config_info': {'model_based_pick': False}},
#  (35,
#   0,
#   71): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.010621160602428764,
#    'n_estimators': 181}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   72): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 18,
#    'min_samples_split': 0.010298279040536028,
#    'n_estimators': 178}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   73): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 12,
#    'min_samples_split': 0.039447437002661595,
#    'n_estimators': 121}, 'config_info': {'model_based_pick': False}},
#  (35,
#   0,
#   74): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.010417871418002843,
#    'n_estimators': 180}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   75): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 16,
#    'min_samples_split': 0.04475072670076225,
#    'n_estimators': 192}, 'config_info': {'model_based_pick': False}},
#  (35,
#   0,
#   76): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 18,
#    'min_samples_split': 0.01035984454391162,
#    'n_estimators': 178}, 'config_info': {'model_based_pick': True}},
#  (35,
#   0,
#   77): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 7,
#    'min_samples_split': 0.027652970280196802,
#    'n_estimators': 53}, 'config_info': {'model_based_pick': False}},
#  (35,
#   0,
#   78): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 4,
#    'min_samples_split': 0.028309140305588246,
#    'n_estimators': 137}, 'config_info': {'model_based_pick': False}},
#  (35,
#   0,
#   79): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 13,
#    'min_samples_split': 0.032674837190499746,
#    'n_estimators': 40}, 'config_info': {'model_based_pick': False}},
#  (35,
#   0,
#   80): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.010109512195126432,
#    'n_estimators': 179}, 'config_info': {'model_based_pick': True}},
#  (36,
#   0,
#   0): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 18,
#    'min_samples_split': 0.010398188967037321,
#    'n_estimators': 177}, 'config_info': {'model_based_pick': True}},
#  (36,
#   0,
#   1): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 20,
#    'min_samples_split': 0.010063739685780159,
#    'n_estimators': 175}, 'config_info': {'model_based_pick': True}},
#  (36,
#   0,
#   2): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.010723460863159283,
#    'n_estimators': 183}, 'config_info': {'model_based_pick': True}},
#  (36,
#   0,
#   3): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.010589063094230817,
#    'n_estimators': 178}, 'config_info': {'model_based_pick': True}},
#  (36,
#   0,
#   4): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 9,
#    'min_samples_split': 0.047134751895169816,
#    'n_estimators': 91}, 'config_info': {'model_based_pick': False}},
#  (36,
#   0,
#   5): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 17,
#    'min_samples_split': 0.010450580249668641,
#    'n_estimators': 178}, 'config_info': {'model_based_pick': True}},
#  (36,
#   0,
#   6): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 18,
#    'min_samples_split': 0.010068002211916517,
#    'n_estimators': 176}, 'config_info': {'model_based_pick': True}},
#  (36,
#   0,
#   7): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 18,
#    'min_samples_split': 0.010557535316542351,
#    'n_estimators': 183}, 'config_info': {'model_based_pick': True}},
#  (36,
#   0,
#   8): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 17,
#    'min_samples_split': 0.010448492650015724,
#    'n_estimators': 177}, 'config_info': {'model_based_pick': True}},
#  (36,
#   0,
#   9): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.010236459397816937,
#    'n_estimators': 178}, 'config_info': {'model_based_pick': True}},
#  (36,
#   0,
#   10): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.010317148797153577,
#    'n_estimators': 179}, 'config_info': {'model_based_pick': True}},
#  (36,
#   0,
#   11): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.01018895218138364,
#    'n_estimators': 179}, 'config_info': {'model_based_pick': True}},
#  (36,
#   0,
#   12): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 17,
#    'min_samples_split': 0.010351916243174782,
#    'n_estimators': 178}, 'config_info': {'model_based_pick': True}},
#  (36,
#   0,
#   13): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 18,
#    'min_samples_split': 0.010686062108198741,
#    'n_estimators': 182}, 'config_info': {'model_based_pick': True}},
#  (36,
#   0,
#   14): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 15,
#    'min_samples_split': 0.01812547858401848,
#    'n_estimators': 196}, 'config_info': {'model_based_pick': False}},
#  (36,
#   0,
#   15): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.010560769561422878,
#    'n_estimators': 176}, 'config_info': {'model_based_pick': True}},
#  (36,
#   0,
#   16): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 11,
#    'min_samples_split': 0.04583305318211964,
#    'n_estimators': 75}, 'config_info': {'model_based_pick': False}},
#  (36,
#   0,
#   17): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.020579276939219224,
#    'n_estimators': 157}, 'config_info': {'model_based_pick': False}},
#  (36,
#   0,
#   18): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 18,
#    'min_samples_split': 0.019551139687893335,
#    'n_estimators': 156}, 'config_info': {'model_based_pick': False}},
#  (36,
#   0,
#   19): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 18,
#    'min_samples_split': 0.010520306694688696,
#    'n_estimators': 177}, 'config_info': {'model_based_pick': True}},
#  (36,
#   0,
#   20): {'config': {'class_weight': 0,
#    'criterion': 1,
#    'max_depth': 17,
#    'min_samples_split': 0.01679879265393503,
#    'n_estimators': 175}, 'config_info': {'model_based_pick': False}},
#  (36,
#   0,
#   21): {'config': {'class_weight': 1,
#    'criterion': 0,
#    'max_depth': 20,
#    'min_samples_split': 0.010329043927665323,
#    'n_estimators': 180}, 'config_info': {'model_based_pick': True}},
#  (36,
#   0,
#   22): {'config': {'class_weight': 1,
#    'criterion': 1,
#    'max_depth': 19,
#    'min_samples_split': 0.010042328351385481,
#    'n_estimators': 180}, 'config_info': {'model_based_pick': True}},
#  ...}

# %% [markdown]
# 이제 최적의 ID에 해당하는 설정을 출력해보자.

# %%
hyperparameters[best_trial_id]
# Out:
# {'config': {'class_weight': 1,
#   'criterion': 1,
#   'max_depth': 20,
#   'min_samples_split': 0.010252955151271581,
#   'n_estimators': 174},
#  'config_info': {'model_based_pick': True}}

# %%
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier


model = RandomForestClassifier(
    random_state=42,
    class_weight='balanced_subsample',
    criterion='entropy',
    max_depth=20,
    min_samples_split=0.010252955151271581,
    n_estimators=174
).fit(X_train, y_train)

y_pred = model.predict(X_test)
f1_score(y_test, y_pred, pos_label=1)
# Out:
# 0.5489398780133605
